# %% [raw]
# 1. Go to website
# 2. Search for a respective product
# 3. Locate review part
# 4. scrap all the data in local system

# %%
pip install Flask-Cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
#go to url
flipkart_url = "https://www.flipkart.com/search?q=" + 'samsungs23'
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=samsungs23'

# %%
#open the url using urlopen
uClient = uReq(flipkart_url)
uClient

# %%
#produce entire page source codes
flipkartPage = uClient.read()
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
#it just beautify the raw html code (little bit readable format)
flipkart_html = bs(flipkartPage, "html.parser")
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
#find all the div classes, it extract the info from avove 
#div", {"class": "_1AtVbE col-12-12 - this is available in raw html
#this defines the phones
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsungs23&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=t
# ...

# %%
#on this page 30 iphones available
len(bigboxes)
# Out:
# 30

# %%
total len is 30 but 24 phone available in that page

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsungs23&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=ty
# ...

# %%
bigboxes[25].div.div.div.a['href']
# Out:
# '/samsung-galaxy-f04-jade-purple-64-gb/p/itm0934dc56a1df7?pid=MOBGKY2VTP3XETBR&lid=LSTMOBGKY2VTP3XETBRJKXEIM&marketplace=FLIPKART&q=samsungs23&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_24&otracker=search&fm=organic&iid=5b3636e8-7d0d-43a9-860c-11605de1ac5f.MOBGKY2VTP3XETBR.SEARCH&ppt=None&ppn=None&ssid=5laqkkcz1s0000001691990456249&qH=576dbe16eda5ba4d'

# %% [raw]
# products are available only from 2 to 26, total 24 products available

# %%
del bigboxes[0:2]

# %%
bigboxes[0].div.div.div.a['href']
# Out:
# '/samsung-galaxy-s23-5g-phantom-black-128-gb/p/itm1f3efe01d1c61?pid=MOBGNPGZVX4PCTTF&lid=LSTMOBGNPGZVX4PCTTFYWYWBL&marketplace=FLIPKART&q=samsungs23&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=5b3636e8-7d0d-43a9-860c-11605de1ac5f.MOBGNPGZVX4PCTTF.SEARCH&ppt=None&ppn=None&ssid=5laqkkcz1s0000001691990456249&qH=576dbe16eda5ba4d'

# %%
productLink = "https://www.flipkart.com" + bigboxes[0].div.div.div.a['href']
productLink
# Out:
# 'https://www.flipkart.com/samsung-galaxy-s23-5g-phantom-black-128-gb/p/itm1f3efe01d1c61?pid=MOBGNPGZVX4PCTTF&lid=LSTMOBGNPGZVX4PCTTFYWYWBL&marketplace=FLIPKART&q=samsungs23&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=5b3636e8-7d0d-43a9-860c-11605de1ac5f.MOBGNPGZVX4PCTTF.SEARCH&ppt=None&ppn=None&ssid=5laqkkcz1s0000001691990456249&qH=576dbe16eda5ba4d'

# %%
prodRes = requests.get(productLink)

# %%
prodRes.encoding='utf-8'
prodRes
# Out:
# <Response [200]>

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Must buy!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Amazing Product, Light Weight, Best Camera, Handy, Compact Premium Smart Phone.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_dcadd731f9914a0fb52916203f200596.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_d504341b8fd54133a4fce4d82e004e45.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Must buy!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Amazing Product, Light Weight, Best Camera, Handy, Compact Premium Smart Phone.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_dcadd731f9914a0fb52916203f200596.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_d504341b8fd54133a4fce4d82e004e45.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_9f6c7b6158bd443ea1957c42ab3f39c0.jpg?q=
# ...

# %%
#extract name of the commentitor
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})
# Out:
# [<p class="_2sc7ZR _2V5EHH">HARSHIL MEHTA</p>]

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'HARSHIL MEHTA'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
# Out:
# HARSHIL MEHTA
# Abhishek  Verma
# Deepak Gowda
# Kishore Charan
# Nagesh
# Gaurav  Apte
# Abhijeet Farakate
# Pranshu  Singh
# Anil Gouda
# Shrirang  Kadam

# %%
#extract rating
commentboxes[2].div.div.div.div.text
# Out:
# '4'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.div.text)
# Out:
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# 5
# 5

# %%
#reviewcomment heading
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.p.text)
# Out:
# Must buy!
# Highly recommended
# Good quality product
# Highly recommended
# Best in the market!
# Wonderful
# Wonderful
# Excellent
# Great product
# Best in the market!

# %%
#combining name with rating
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.div.p.text)
    comtag = commentboxes[i].div.div.find_all('div', {'class': ''})
    print(comtag[0].div.text)
    print("\n")
# Out:
# HARSHIL MEHTA
# 5
# Must buy!
# Amazing Product, Light Weight, Best Camera, Handy, Compact Premium Smart Phone.
#
#
# Abhishek  Verma
# 5
# Highly recommended
# Amazing camera, good feel in hand, good battery
#
#
# Deepak Gowda
# 4
# Good quality product
# Nice phone with best camera. Face id recognization average..
#
#
# Kishore Charan
# 5
# Highly recommended
# This time Samsung does very well. Currently Best Premium Smartphone in market.
#
#
# Nagesh
# 5
# Best in the market!
# Amazing camera and Good performance..best choice
#
#
# Gaurav  Apte
# 5
# Wonderful
# Portrait mode is excellent.Night mode performance is very good.pictures are clear and sharp.Charging speed could have been better but yes battery is optimised very well so easily lasts for a day.
#
#
# Abhijeet Farakate
# 4
# Wonderful
# ...
